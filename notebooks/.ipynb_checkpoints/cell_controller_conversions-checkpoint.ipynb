# %%
import numpy as np
import csv
import struct
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # RESISTIVE PULSE

# %%
file_directory = '/home/prestonh/Desktop/Research/cancer_cells/data/1-27-2017/'
file_name = 'test_rp_0'
file_path = file_directory + file_name
file_handle = open(file_path, 'r')
file_reader = csv.reader(file_handle)

new_file_path = file_path + '.bts'
new_file_handle = open(new_file_path, 'wb')

# %%
current = []
for row in file_reader:
    current.append(float(row[0]))
current = np.array(current)
print current
time = np.array([i*1./250000 for i in xrange(len(current))])

print time.shape, current.shape

data = np.hstack((time, current))
# Out:
# []
# (0,) (0,)

# %%
print data.shape
# Out:
# (0,)

# %%
plt.plot(time, data)
#plt.xlim(21400,21600)
plt.show()
