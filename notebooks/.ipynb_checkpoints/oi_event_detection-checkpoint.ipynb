# %% [markdown]
# # Finds optical events in a video file

# %% [markdown]
# ### Imports

# %%
# Python standard library
import sys
import os

# Scipy
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Program specific
PORE_STATS_BASE_DIRECTORY = os.getcwd().replace('notebooks', '')
sys.path.append(PORE_STATS_BASE_DIRECTORY + '/pore_stats/oi/')
import optical_imaging as oi
import oi_file

# %% [markdown]
# ### Load data

# %%
# Define file path
data_base_path = '/home/prestonh/Desktop/Research/cancer_cells/data'
date = '/3-3-2017'
particle_type = '/HCT-116'
channel_type = '/17p5_30_17p5'
file_index = '5'
file_path = data_base_path + date + particle_type + channel_type + '/oi/bin/test_camera_' + file_index

# Set output file path
output_file_path = file_path + '_events.json'

# Open video
oi_vid = oi_file.Raw(file_path, 512, 288, 50000, 5)

# %% [markdown]
# ### Find a frame that has a cluster

# %%
template_index = 0
template_frame = oi_vid.get_frame(template_index)
plt.imshow(template_frame, cmap = 'gray', origin = 'lower')
plt.show()

# %%
threshold_difference = 0.02

num_found = 0
for i in range(0, oi_vid._total_frames):
    if i%1000 == 0:
        print i
    frame = oi_vid.get_frame(i)
    clusters = oi.find_clusters_percentage_based(frame, template_frame, threshold_difference = threshold_difference)
    if(len(clusters)) > 0:
        print i
        num_found+=1
        if num_found > 5:
            #break
            pass
# Out:
# 0
# 1000
# 1303
# 1304
# 1305
# 1306
# 1307
# 1308
# 1309
# 1310
# 1311
# 1312
# 1313
# 1314
# 1315
# 1316
# 1317
# 1318
# 1319
# 1320
# 1321
# 1322
# 1323
# 1324
# 1325
# 1326
# 1327
# 1328
# 1329
# 1330
# 1331
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-56d4bcaeb0a1> in <module>()
#       6         print i
#       7     frame = oi_vid.get_frame(i)
# ----> 8     clusters = oi.find_clusters_percentage_based(frame, template_frame, threshold_difference = threshold_difference)
#       9     if(len(clusters)) > 0:
#      10         print i
#
# /home/prestonh/Desktop/Research/pore_stats//pore_stats/oi/optical_imaging.pyc in find_clusters_percentage_based(frame, template_frame, threshold_difference, cluster_threshold, diag)
#     761         if pixel_check_array[i,j] == 1:
#     762             cluster_pixels, pixel_check_array=add_pixel_to_cluster\
# --> 763             (negative_frame, pixel_check_array, i, j, threshold_difference, diag = diag)
#     764
#     765             if cluster_pixels.shape[0] > cluster_threshold:
#
# /home/prestonh/Desktop/Research/pore_stats//pore_stats/oi/optical_imaging.pyc in add_pixel_to_cluster(negative_frame, pixel_check_array, i, j, threshold_difference, cluster_pixels, direction, diag)
#     803     # Right
#     804     if (direction != 'right' and j != negative_frame.shape[1] -1
# --> 805         and pixel_check_array[i,j+1] == 1):
#     806         if negative_frame[i,j+1]>=threshold_difference:
#     807             cluster_pixels, pixel_check_array=add_pixel_to_cluster(
#
# KeyboardInterrupt:

# %% [markdown]
# ### Show image, template image, difference

# %%
index = 1320

template_frame = oi_vid.get_frame(template_index)
frame = oi_vid.get_frame(index)

threshold_difference = .015#.035
alpha = 1#2



beta = 'avg'    # -(np.mean(frame)-.5)
#template_frame = oi.change_frame_contrast(template_frame, alpha = alpha, beta = beta)
#frame = oi.change_frame_contrast(frame, alpha = alpha, beta = beta)


cluster_threshold = 200


neg_frame = abs(frame - template_frame)
clusters = oi.find_clusters_percentage_based(frame, template_frame, threshold_difference = threshold_difference,\
                                             cluster_threshold = cluster_threshold)
temp_neg_frame = np.copy(neg_frame)
temp_neg_frame[temp_neg_frame > threshold_difference] = 1
temp_neg_frame[temp_neg_frame <= threshold_difference] = 0

print len(clusters)
fig, axes = plt.subplots(1,3,figsize=(24,8))

# Raw image
plt.sca(axes[0])
plt.imshow(frame, cmap = 'gray', origin = 'lower')

# Negative
plt.sca(axes[1])
plt.imshow(neg_frame, cmap = 'gray', vmin = 0, vmax = 1, origin = 'lower')

# Thresholded negative
plt.sca(axes[2])
plt.imshow(temp_neg_frame, vmin = 0, vmax = 1, cmap = 'gray', origin = 'lower')

plt.show()
# Out:
# 1

# %% [markdown]
# ### Find events

# %%
reload(oi)
alpha = 1
beta = 'avg'
raw_events = oi.find_events(oi_vid, ti = 0, template_frame = oi_vid.get_frame(template_index), threshold_difference = threshold_difference, cluster_threshold = cluster_threshold, alpha = alpha, beta = 'avg')
# Out:
# /home/prestonh/Desktop/Research/pore_stats//pore_stats/oi/optical_imaging.py:1120: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if template_frame == None:
# t:  0 / 49974 	clusters: 0 	active: 0 	inactive: 0
# t:  1000 / 49974 	clusters: 0 	active: 0 	inactive: 0
# /home/prestonh/Desktop/Research/pore_stats//pore_stats/oi/optical_imaging.py:62: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if pixels != None:
# t:  2000 / 49974 	clusters: 0 	active: 0 	inactive: 1
# t:  3000 / 49974 	clusters: 0 	active: 0 	inactive: 1
# t:  4000 / 49974 	clusters: 0 	active: 0 	inactive: 2
# t:  5000 / 49974 	clusters: 0 	active: 0 	inactive: 2
# t:  6000 / 49974 	clusters: 0 	active: 0 	inactive: 2
# t:  7000 / 49974 	clusters: 0 	active: 0 	inactive: 2
# t:  8000 / 49974 	clusters: 0 	active: 0 	inactive: 3
# t:  9000 / 49974 	clusters: 0 	active: 0 	inactive: 5
# t:  10000 / 49974 	clusters: 0 	active: 0 	inactive: 7
# t:  11000 / 49974 	clusters: 0 	active: 0 	inactive: 7
# t:  12000 / 49974 	clusters: 0 	active: 0 	inactive: 7
# t:  13000 / 49974 	clusters: 1 	active: 1 	inactive: 7
# t:  14000 / 49974 	clusters: 0 	active: 0 	inactive: 8
# t:  15000 / 49974 	clusters: 0 	active: 0 	inactive: 8
# t:  16000 / 49974 	clusters: 0 	active: 0 	inactive: 8
# t:  17000 / 49974 	clusters: 0 	active: 0 	inactive: 8
# t:  18000 / 49974 	clusters: 0 	active: 0 	inactive: 12
# t:  19000 / 49974 	clusters: 0 	active: 0 	inactive: 15
# t:  20000 / 49974 	clusters: 0 	active: 0 	inactive: 15
# t:  21000 / 49974 	clusters: 0 	active: 0 	inactive: 16
# t:  22000 / 49974 	clusters: 0 	active: 0 	inactive: 16
# t:  23000 / 49974 	clusters: 0 	active: 0 	inactive: 20
# t:  24000 / 49974 	clusters: 0 	active: 0 	inactive: 25
# t:  25000 / 49974 	clusters: 0 	active: 0 	inactive: 25
# t:  26000 / 49974 	clusters: 0 	active: 0 	inactive: 29
# t:  27000 / 49974 	clusters: 0 	active: 0 	inactive: 33
# t:  28000 / 49974 	clusters: 0 	active: 0 	inactive: 33
# t:  29000 / 49974 	clusters: 0 	active: 0 	inactive: 39
# t:  30000 / 49974 	clusters: 0 	active: 0 	inactive: 67
# t:  31000 / 49974 	clusters: 0 	active: 0 	inactive: 79
# t:  32000 / 49974 	clusters: 0 	active: 0 	inactive: 80
# t:  33000 / 49974 	clusters: 0 	active: 0 	inactive: 84
# t:  34000 / 49974 	clusters: 0 	active: 0 	inactive: 87
# t:  35000 / 49974 	clusters: 0 	active: 0 	inactive: 94
# t:  36000 / 49974 	clusters: 0 	active: 0 	inactive: 94
# t:  37000 / 49974 	clusters: 0 	active: 0 	inactive: 100
# t:  38000 / 49974 	clusters: 0 	active: 0 	inactive: 102
# t:  39000 / 49974 	clusters: 0 	active: 0 	inactive: 102
# t:  40000 / 49974 	clusters: 0 	active: 0 	inactive: 104
# t:  41000 / 49974 	clusters: 0 	active: 0 	inactive: 109
# t:  42000 / 49974 	clusters: 0 	active: 0 	inactive: 111
# t:  43000 / 49974 	clusters: 0 	active: 0 	inactive: 122
# t:  44000 / 49974 	clusters: 0 	active: 0 	inactive: 125
# t:  45000 / 49974 	clusters: 0 	active: 0 	inactive: 125
# t:  46000 / 49974 	clusters: 1 	active: 1 	inactive: 128
# t:  47000 / 49974 	clusters: 0 	active: 0 	inactive: 130
# t:  48000 / 49974 	clusters: 0 	active: 0 	inactive: 131
# t:  49000 / 49974 	clusters: 0 	active: 0 	inactive: 131

# %% [markdown]
# ### Inspect trajectories

# %%
fig = plt.figure(figsize = (20,12))
for i, event in enumerate(raw_events[:]):
    px = []
    py = []
    for detection in event._detections:
        px.append(detection._px)
        py.append(detection._py)
    plt.plot(px, py, lw = 2)

plt.imshow(template_frame, alpha=0.8, cmap = 'gray', origin = 'lower')
plt.xticks([])
plt.yticks([])

fig.tight_layout()


plt.show()

# %% [markdown]
# ### Save events

# %%
print output_file_path
# Out:
# /home/prestonh/Desktop/Research/cancer_cells/data/3-3-2017/HCT-116/17p5_30_17p5/oi/bin/test_camera_5_events.json

# %%
oi_file.save_oi_events_json(output_file_path, raw_events)
